# %%
# -*- coding: utf-8 -*-
# isbul.net — TÜM İLANLAR (liste + detay zenginleştirme, JSON-LD destekli)
import os, time, random, json, html, re
import pandas as pd
from bs4 import BeautifulSoup

import undetected_chromedriver as uc
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC

# =================== AYARLAR ===================
BASE_URL     = "https://www.isbul.net/is-ilanlari"
MAX_PAGES    = 50
CSV_PATH     = "isbul_tr_is_ilanlari.csv"
LIST_DELAY   = (0.25, 0.6)
DETAIL_DELAY = (0.6, 1.4)
WAIT         = 18
HEADLESS     = False

PROFILE_DIR = os.path.expanduser("~/uc_profiles/isbul_profile")
os.makedirs(PROFILE_DIR, exist_ok=True)
# =================================================

def start_driver():
    opts = uc.ChromeOptions()
    opts.add_argument("--lang=tr-TR")
    opts.add_argument("--disable-blink-features=AutomationControlled")
    opts.add_argument(f"--user-data-dir={PROFILE_DIR}")
    opts.add_argument("--window-size=1280,900")
    if HEADLESS:
        opts.add_argument("--headless=new")
    return uc.Chrome(options=opts)

def soup_now(driver):
    return BeautifulSoup(driver.page_source, "html.parser")

def clean_text(t):
    if not t: return None
    t = html.unescape(t)
    t = re.sub(r"\s+", " ", t).strip()
    return t or None

def first_select(soup_or_el, selectors):
    for sel in selectors:
        try:
            hit = soup_or_el.select_one(sel)
            if hit: return hit
        except: pass
    return None

def click_any(driver, selectors):
    for sel in selectors:
        try:
            el = driver.find_element(By.CSS_SELECTOR, sel)
            driver.execute_script("arguments[0].click();", el)
            return True
        except: pass
    return False

def go_to_page(driver, p):
    url = BASE_URL if p == 1 else f"{BASE_URL}?sf={p}"
    driver.get(url)
    WebDriverWait(driver, WAIT).until(EC.presence_of_element_located((By.TAG_NAME, "body")))
    # çerez/popup kapat
    click_any(driver, [
        "button[aria-label*='Kabul' i]", "button[aria-label*='Accept' i]",
        "button[aria-label='Kapat']", ".cookie-accept", "button.cookie-accept"
    ])
    time.sleep(random.uniform(*LIST_DELAY))

def collect_from_list(driver, page_index):
    # Lazy load için aşağı kay
    for _ in range(6):
        driver.find_element(By.TAG_NAME, "body").send_keys(Keys.END)
        time.sleep(0.12)
    sp = soup_now(driver)

    list_selectors = ["div.job-list", "ul.job-list", "div.list", "div#jobs", "div.ilan-listesi"]
    card_selectors = ["div.job-list > div", "ul.job-list > li", "div.ilan", "div.job-item", "div.list > div", "div.ilan-karti"]

    container = first_select(sp, list_selectors) or sp
    cards = []
    for sel in card_selectors:
        found = container.select(sel)
        if found: cards = found; break
    if not cards:
        cards = [a.parent for a in sp.select("a[href*='/is-ilani/']")]

    rows = []
    for c in cards:
        a = first_select(c, ["a[href*='/is-ilani/']", "a.job-title", "a.title", "h2 a"])
        href = a.get("href") if a else None
        if href and href.startswith("/"):
            href = "https://www.isbul.net" + href
        title = clean_text(a.get_text(" ", strip=True)) if a else None
        if not title:
            h2 = first_select(c, ["h2", ".job-title", ".title"])
            title = clean_text(h2.get_text(" ", strip=True)) if h2 else None
        if title and href:
            rows.append({"Title": title, "Link": href, "Page": page_index})
    return rows

# ---------- JSON-LD parse ----------
def parse_jobposting_jsonld(sp: BeautifulSoup):
    """
    Sayfadaki tüm application/ld+json scriptlerini dolaşır.
    JobPosting şemasından şirket/konum/description çeker.
    """
    company = location = summary = None
    scripts = sp.find_all("script", type=lambda x: x and "ld+json" in x)
    for sc in scripts:
        try:
            raw = sc.string or sc.get_text()
            if not raw: continue
            data = json.loads(raw)
            # bazen list olur
            cand = data if isinstance(data, list) else [data]
            for obj in cand:
                if not isinstance(obj, dict): continue
                t = obj.get("@type") or obj.get("type")
                if (isinstance(t, list) and "JobPosting" in t) or t == "JobPosting":
                    # company
                    org = obj.get("hiringOrganization")
                    if isinstance(org, dict):
                        company = company or clean_text(org.get("name"))
                    # location
                    jobloc = obj.get("jobLocation")
                    if isinstance(jobloc, list) and jobloc:
                        addr = jobloc[0].get("address") if isinstance(jobloc[0], dict) else None
                    elif isinstance(jobloc, dict):
                        addr = jobloc.get("address")
                    else:
                        addr = None
                    if isinstance(addr, dict):
                        location = location or clean_text(addr.get("addressLocality") or addr.get("addressRegion") or addr.get("addressCountry"))
                    # summary/description
                    desc = obj.get("description") or obj.get("responsibilities")
                    if desc:
                        # HTML içeriği sadeleştir
                        summary = summary or clean_text(BeautifulSoup(desc, "html.parser").get_text(" ", strip=True))
                    # erken çıkış: üçünden biri bulunduysa bile devam edip kalanları doldurabiliriz
        except Exception:
            continue
    return company, location, summary

def enrich_with_details(driver, row, retries=2):
    """
    Detay sayfasına girer. Önce JSON-LD, sonra HTML seçicileriyle Company/Location/Summary doldurur.
    """
    attempt = 0
    while attempt <= retries:
        try:
            driver.get(row["Link"])
            WebDriverWait(driver, WAIT).until(EC.presence_of_element_located((By.TAG_NAME, "body")))
            time.sleep(random.uniform(*DETAIL_DELAY))

            sp = soup_now(driver)

            # 1) JSON-LD
            company, location, summary = parse_jobposting_jsonld(sp)

            # 2) HTML fallback (görsel metin)
            if not company:
                company = clean_text((first_select(sp, [
                    ".firma-adi", ".company", ".ilan-firma", ".job-company",
                    "h2.company-name", "span.company-name", "div.company-name", "a.company"
                ]) or {}).get_text(" ", strip=True) if first_select(sp, [
                    ".firma-adi", ".company", ".ilan-firma", ".job-company",
                    "h2.company-name", "span.company-name", "div.company-name", "a.company"
                ]) else None)

            if not location:
                location = clean_text((first_select(sp, [
                    ".sehir", ".location", "span.city", "span.job-location",
                    "li.location", "div.location", "p.location"
                ]) or {}).get_text(" ", strip=True) if first_select(sp, [
                    ".sehir", ".location", "span.city", "span.job-location",
                    "li.location", "div.location", "p.location"
                ]) else None)

            if not summary:
                desc_el = first_select(sp, [
                    ".ilan-aciklama", ".description", ".job-desc", "div.job-description",
                    "section.job-description", "div#ilan-detay", ".ilan-detay", "article"
                ])
                if desc_el:
                    summary = clean_text(desc_el.get_text(" ", strip=True))

            # uzun özetleri kısalt
            if summary and len(summary) > 500:
                summary = summary[:497] + "…"

            row["Company"]  = company
            row["Location"] = location
            row["Summary"]  = summary
            return row

        except Exception:
            attempt += 1
            time.sleep(0.6)

    # başarısız olursa boş bırak ama satırı döndür
    return row

# ------------------- ÇALIŞTIR -------------------
driver = start_driver()
all_rows, seen = [], set()

try:
    for page in range(1, MAX_PAGES + 1):
        go_to_page(driver, page)
        list_rows = collect_from_list(driver, page)
        fresh = [r for r in list_rows if r["Link"] not in seen]
        for r in fresh: seen.add(r["Link"])

        print(f"Sayfa {page}: bulunan {len(list_rows)}, yeni {len(fresh)}, toplam {len(all_rows)+len(fresh)}")

        if page > 1 and len(list_rows) == 0:
            print("Boş sayfa geldi, durduruyorum.")
            break

        # Detay zenginleştir
        for r in fresh:
            enr = enrich_with_details(driver, r)
            all_rows.append(enr)
            time.sleep(random.uniform(*LIST_DELAY))

        # ara kayıt
        if page % 5 == 0:
            pd.DataFrame(all_rows).to_csv(CSV_PATH, index=False)
            print(f"[Ara kayıt] CSV güncellendi: {CSV_PATH}")

    df = pd.DataFrame(all_rows)
    display(df.head(30))
    df.to_csv(CSV_PATH, index=False)
    print("CSV kaydedildi:", CSV_PATH)
    print(f"Toplam {len(df)} ilan kaydedildi.")

finally:
    try: driver.quit()
    except: pass
# Out:
# Sayfa 1: bulunan 70, yeni 70, toplam 70
# /var/folders/_q/p66_q3xn4nvf990hv_wtwb2c0000gn/T/ipykernel_3866/2258732449.py:142: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   summary = summary or clean_text(BeautifulSoup(desc, "html.parser").get_text(" ", strip=True))
# Sayfa 2: bulunan 70, yeni 0, toplam 70
# Sayfa 3: bulunan 70, yeni 0, toplam 70
# Sayfa 4: bulunan 70, yeni 0, toplam 70
# Sayfa 5: bulunan 70, yeni 0, toplam 70
# [Ara kayıt] CSV güncellendi: isbul_tr_is_ilanlari.csv
# Sayfa 6: bulunan 70, yeni 0, toplam 70
# Sayfa 7: bulunan 70, yeni 0, toplam 70
# Sayfa 8: bulunan 70, yeni 0, toplam 70
# Sayfa 9: bulunan 70, yeni 0, toplam 70
# Sayfa 10: bulunan 70, yeni 0, toplam 70
# [Ara kayıt] CSV güncellendi: isbul_tr_is_ilanlari.csv
# Sayfa 11: bulunan 70, yeni 0, toplam 70
# Sayfa 12: bulunan 70, yeni 0, toplam 70
# Sayfa 13: bulunan 70, yeni 0, toplam 70
# Sayfa 14: bulunan 70, yeni 0, toplam 70
# Sayfa 15: bulunan 70, yeni 0, toplam 70
# [Ara kayıt] CSV güncellendi: isbul_tr_is_ilanlari.csv
# Sayfa 16: bulunan 70, yeni 0, toplam 70
# Sayfa 17: bulunan 70, yeni 0, toplam 70
# Sayfa 18: bulunan 70, yeni 0, toplam 70
# Sayfa 19: bulunan 70, yeni 0, toplam 70
# Sayfa 20: bulunan 70, yeni 0, toplam 70
# [Ara kayıt] CSV güncellendi: isbul_tr_is_ilanlari.csv
# Sayfa 21: bulunan 70, yeni 0, toplam 70
# Sayfa 22: bulunan 70, yeni 0, toplam 70
# Sayfa 23: bulunan 70, yeni 0, toplam 70
# Sayfa 24: bulunan 70, yeni 0, toplam 70
# Sayfa 25: bulunan 70, yeni 0, toplam 70
# [Ara kayıt] CSV güncellendi: isbul_tr_is_ilanlari.csv
# Sayfa 26: bulunan 70, yeni 0, toplam 70
# Sayfa 27: bulunan 70, yeni 0, toplam 70
# Sayfa 28: bulunan 70, yeni 0, toplam 70
# Sayfa 29: bulunan 70, yeni 0, toplam 70
# Sayfa 30: bulunan 70, yeni 0, toplam 70
# [Ara kayıt] CSV güncellendi: isbul_tr_is_ilanlari.csv
# Sayfa 31: bulunan 70, yeni 0, toplam 70
# Sayfa 32: bulunan 70, yeni 0, toplam 70
# Sayfa 33: bulunan 70, yeni 0, toplam 70
# Sayfa 34: bulunan 70, yeni 0, toplam 70
# Sayfa 35: bulunan 70, yeni 0, toplam 70
# [Ara kayıt] CSV güncellendi: isbul_tr_is_ilanlari.csv
# Sayfa 36: bulunan 70, yeni 0, toplam 70
# Sayfa 37: bulunan 70, yeni 0, toplam 70
# Sayfa 38: bulunan 70, yeni 0, toplam 70
# Sayfa 39: bulunan 70, yeni 0, toplam 70
# Sayfa 40: bulunan 70, yeni 0, toplam 70
# [Ara kayıt] CSV güncellendi: isbul_tr_is_ilanlari.csv
# Sayfa 41: bulunan 70, yeni 0, toplam 70
# Sayfa 42: bulunan 70, yeni 0, toplam 70
# Sayfa 43: bulunan 70, yeni 0, toplam 70
# Sayfa 44: bulunan 70, yeni 0, toplam 70
# Sayfa 45: bulunan 70, yeni 0, toplam 70
# [Ara kayıt] CSV güncellendi: isbul_tr_is_ilanlari.csv
# Sayfa 46: bulunan 70, yeni 0, toplam 70
# Sayfa 47: bulunan 70, yeni 0, toplam 70
# Sayfa 48: bulunan 70, yeni 0, toplam 70
# Sayfa 49: bulunan 70, yeni 0, toplam 70
# Sayfa 50: bulunan 70, yeni 0, toplam 70
# [Ara kayıt] CSV güncellendi: isbul_tr_is_ilanlari.csv
#                                            Title  \
# 0                             Müşteri Temsilcisi
# 1                             Müşteri Temsilcisi
# 2   Konsolosluk Vize Ve İkamet Başvuru Danışmanı
# 3   Konsolosluk Vize Ve İkamet Başvuru Danışmanı
# 4                  Elektrik-elektronik Mühendisi
# 5                  Elektrik-elektronik Mühendisi
# 6                          Tam Zamanlı Teknisyen
# 7                          Tam Zamanlı Teknisyen
# 8                                    Ön Muhasebe
# 9                                    Ön Muhasebe
# 10                              Eğitim Danışmanı
# 11                              Eğitim Danışmanı
# 12                       Sekreter - Ofis Elemanı
# 13                       Sekreter - Ofis Elemanı
# 14                            Temizlik Personeli
# 15                            Temizlik Personeli
# 16                              Abkant Operatörü
# 17                              Abkant Operatörü
# 18                  Eğitim Danışmanı Kayıt Kabul
# 19                  Eğitim Danışmanı Kayıt Kabul
# 20                         Gayrimenkul Danışmanı
# 21                         Gayrimenkul Danışmanı
# 22                                       Barista
# 23                                       Barista
# 24                 Radyo Programı Sunacak Spiker
# 25                 Radyo Programı Sunacak Spiker
# 26              Çağrı Merkezi Müşteri Temsilcisi
# 27              Çağrı Merkezi Müşteri Temsilcisi
# 28                         Mağaza - Depo Elemanı
# 29                         Mağaza - Depo Elemanı
#
#                                                  Link  Page  \
# 0   https://www.isbul.net/is-ilani/satis-ve-pazarl...     1
# 1   https://www.isbul.net/is-ilani/satis-ve-pazarl...     1
# 2   https://www.isbul.net/is-ilani/vize-ve-ikamet-...     1
# 3   https://www.isbul.net/is-ilani/vize-ve-ikamet-...     1
# 4         https://www.isbul.net/is-ilani/elekt-309864     1
# 5         https://www.isbul.net/is-ilani/elekt-309864     1
# 6         https://www.isbul.net/is-ilani/tam-a-309868     1
# 7         https://www.isbul.net/is-ilani/tam-a-309868     1
# 8   https://www.isbul.net/is-ilani/on-muhasebe-309866     1
# 9   https://www.isbul.net/is-ilani/on-muhasebe-309866     1
# 10  https://www.isbul.net/is-ilani/egitim-danisman...     1
# 11  https://www.isbul.net/is-ilani/egitim-danisman...     1
# 12     https://www.isbul.net/is-ilani/sekretrr-339784     1
# 13     https://www.isbul.net/is-ilani/sekretrr-339784     1
# 14  https://www.isbul.net/is-ilani/temizlik-person...     1
# 15  https://www.isbul.net/is-ilani/temizlik-person...     1
# 16  https://www.isbul.net/is-ilani/abkant-operator...     1
# 17  https://www.isbul.net/is-ilani/abkant-operator...     1
# 18  https://www.isbul.net/is-ilani/egitim-danisman...     1
# 19  https://www.isbul.net/is-ilani/egitim-danisman...     1
# 20            https://www.isbul.net/is-ilani/g-339766     1
# 21            https://www.isbul.net/is-ilani/g-339766     1
# 22         https://www.isbul.net/is-ilani/bris-339782     1
# 23         https://www.isbul.net/is-ilani/bris-339782     1
# 24  https://www.isbul.net/is-ilani/radyo-programci...     1
# 25  https://www.isbul.net/is-ilani/radyo-programci...     1
# 26  https://www.isbul.net/is-ilani/cagri-merkezi-m...     1
# 27  https://www.isbul.net/is-ilani/cagri-merkezi-m...     1
# 28  https://www.isbul.net/is-ilani/magaza-depo-ele...     1
# 29  https://www.isbul.net/is-ilani/magaza-depo-ele...     1
#
#                                               Company            Location  \
# 0           EA GLOBAL SU ARIt.SİST.SAN.VE TİC.LTD ŞTİ               İzmir
# 1           EA GLOBAL SU ARIt.SİST.SAN.VE TİC.LTD ŞTİ               İzmir
# 2               Trapasaport Vize Dan.Turz.Sey.Ltd.Şti              Ankara
# 3               Trapasaport Vize Dan.Turz.Sey.Ltd.Şti              Ankara
# 4                                 MHYS ENERJİ MÜH.AŞ.              Ankara
# 5                                 MHYS ENERJİ MÜH.AŞ.              Ankara
# 6    SYA OTOMOTİV ARAÇ ÜSTÜ EKİPM. SAN.VE TİC.LTD ŞTİ               İzmir
# 7    SYA OTOMOTİV ARAÇ ÜSTÜ EKİPM. SAN.VE TİC.LTD ŞTİ               İzmir
# 8                                   SENOL SAHIN ILGIN   İstanbul - Avrupa
# 9                                   SENOL SAHIN ILGIN   İstanbul - Avrupa
# 10             MASTER OF ENGLISH ÖZEL EĞ.HİZ.LTD ŞTİ.  İstanbul - Anadolu
# 11             MASTER OF ENGLISH ÖZEL EĞ.HİZ.LTD ŞTİ.  İstanbul - Anadolu
# 12                                       ALİŞAN ALTAN              Ankara
# 13                                       ALİŞAN ALTAN              Ankara
# 14                   KERVAN BACA TEM.HİZ.TİC LTD ŞTİ.  İstanbul - Anadolu
# 15                   KERVAN BACA TEM.HİZ.TİC LTD ŞTİ.  İstanbul - Anadolu
# 16  Y.D.Ç METAL MAK.OTO. NAK. İNŞ TUR. İTH. İHR. S...               İzmir
# 17  Y.D.Ç METAL MAK.OTO. NAK. İNŞ TUR. İTH. İHR. S...               İzmir
# 18                    PERKA EĞİTİM VE DAN.HİZ.LTD ŞTİ   İstanbul - Avrupa
# 19                    PERKA EĞİTİM VE DAN.HİZ.LTD ŞTİ   İstanbul - Avrupa
# 20                 AYŞE ŞAYLI -TERRAHOMES GAYRİMENKUL             Antalya
# 21                 AYŞE ŞAYLI -TERRAHOMES GAYRİMENKUL             Antalya
# 22                                Firma Bilgisi Gizli               İzmir
# 23                                Firma Bilgisi Gizli               İzmir
# 24                                        Radyo Hayat              Amasya
# 25                                        Radyo Hayat              Amasya
# 26                                Omeb Grup Ltd. Şti.              Ankara
# 27                                Omeb Grup Ltd. Şti.              Ankara
# 28  Artek Elektrikli Ev Aletleri San. ve Tic. Ltd....   İstanbul - Avrupa
# 29  Artek Elektrikli Ev Aletleri San. ve Tic. Ltd....   İstanbul - Avrupa
#
#                                               Summary
# 0   EA GLOBAL firması olarak, su arıtma cihazları ...
# 1   EA GLOBAL firması olarak, su arıtma cihazları ...
# 2   Pozisyon: Konsolosluk Vize ve İkamet Başvuru D...
# 3   Pozisyon: Konsolosluk Vize ve İkamet Başvuru D...
# 4   İş ilanı hakkındaMHYS Enerji, geliştirdiği yen...
# 5   İş ilanı hakkındaMHYS Enerji, geliştirdiği yen...
# 6   Kamu ve özel sektöre mobil araç imalatı yapan ...
# 7   Kamu ve özel sektöre mobil araç imalatı yapan ...
# 8   Şişli Bomonti’deki Hukuk Büromuza Yeni Bir Ön ...
# 9   Şişli Bomonti’deki Hukuk Büromuza Yeni Bir Ön ...
# 10  İş Tanımı:Master of English Dil Kursu olarak, ...
# 11  İş Tanımı:Master of English Dil Kursu olarak, ...
# 12  Çayyolu'nda bulunan araç/filo kiralama ve araç...
# 13  Çayyolu'nda bulunan araç/filo kiralama ve araç...
# 14  📢 İŞ İLANI – SAHA PERSONELİ (ENDÜSTRİYEL MUTFA...
# 15  📢 İŞ İLANI – SAHA PERSONELİ (ENDÜSTRİYEL MUTFA...
# 16  Kemalpaşada bulunan metal işleme fabrikamıza d...
# 17  Kemalpaşada bulunan metal işleme fabrikamıza d...
# 18  İş İlanı: Eğitim DanışmanıGüngören Birey Eğiti...
# 19  İş İlanı: Eğitim DanışmanıGüngören Birey Eğiti...
# 20  Terra Home's Gayrimenkul Ailesine Katıl!Gayrim...
# 21  Terra Home's Gayrimenkul Ailesine Katıl!Gayrim...
# 22  Ox Coffee Eat Yeni Foça Marina Isletmesinde Gö...
# 23  Ox Coffee Eat Yeni Foça Marina Isletmesinde Gö...
# 24  Radyo istasyonumuz 95.5 frekansında Amasya ili...
# 25  Radyo istasyonumuz 95.5 frekansında Amasya ili...
# 26  Çayyolu'nda faaliyet gösteren kozmetik ve kişi...
# 27  Çayyolu'nda faaliyet gösteren kozmetik ve kişi...
# 28  ARTEK ELEKTRİKLİ EV ALETLERİ YEDEK PARÇA TOPTA...
# 29  ARTEK ELEKTRİKLİ EV ALETLERİ YEDEK PARÇA TOPTA...
# CSV kaydedildi: isbul_tr_is_ilanlari.csv
# Toplam 70 ilan kaydedildi.
